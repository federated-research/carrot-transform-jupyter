# %% [markdown]
# # Carrot Transform
#
# Converting data to OMOP CDM format using the test dataset.

# %% [markdown]
# ## Install carrot-transform
#
# Install it in the notebook environment:

# %%
# %pip install carrot-transform
# Out:
# Collecting carrot-transform
#   Downloading carrot_transform-0.6.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting awscli>=1.42.74 (from carrot-transform)
#   Downloading awscli-1.44.13-py3-none-any.whl.metadata (11 kB)
# Collecting boto3>=1.40.74 (from carrot-transform)
#   Downloading boto3-1.42.23-py3-none-any.whl.metadata (6.8 kB)
# Collecting click<9,>=8.1.7 (from carrot-transform)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting psycopg2-binary>=2.9.10 (from carrot-transform)
#   Using cached psycopg2_binary-2.9.11-cp314-cp314-macosx_10_13_x86_64.whl.metadata (4.9 kB)
# Collecting sqlalchemy>=2.0.42 (from carrot-transform)
#   Downloading sqlalchemy-2.0.45-py3-none-any.whl.metadata (9.5 kB)
# Collecting trino>=0.335.0 (from carrot-transform)
#   Using cached trino-0.336.0-py3-none-any.whl.metadata (20 kB)
# Collecting botocore==1.42.23 (from awscli>=1.42.74->carrot-transform)
#   Downloading botocore-1.42.23-py3-none-any.whl.metadata (5.9 kB)
# Collecting docutils<=0.19,>=0.18.1 (from awscli>=1.42.74->carrot-transform)
#   Downloading docutils-0.19-py3-none-any.whl.metadata (2.7 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from awscli>=1.42.74->carrot-transform)
#   Downloading s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: PyYAML<6.1,>=3.10 in ./.venv/lib/python3.14/site-packages (from awscli>=1.42.74->carrot-transform) (6.0.3)
# Collecting colorama<0.4.7,>=0.2.5 (from awscli>=1.42.74->carrot-transform)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting rsa<4.8,>=3.1.2 (from awscli>=1.42.74->carrot-transform)
#   Downloading rsa-4.7.2-py3-none-any.whl.metadata (3.6 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from botocore==1.42.23->awscli>=1.42.74->carrot-transform)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in ./.venv/lib/python3.14/site-packages (from botocore==1.42.23->awscli>=1.42.74->carrot-transform) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in ./.venv/lib/python3.14/site-packages (from botocore==1.42.23->awscli>=1.42.74->carrot-transform) (2.6.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.14/site-packages (from python-dateutil<3.0.0,>=2.1->botocore==1.42.23->awscli>=1.42.74->carrot-transform) (1.17.0)
# Collecting pyasn1>=0.1.3 (from rsa<4.8,>=3.1.2->awscli>=1.42.74->carrot-transform)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting greenlet>=1 (from sqlalchemy>=2.0.42->carrot-transform)
#   Downloading greenlet-3.3.0-cp314-cp314-macosx_11_0_universal2.whl.metadata (4.1 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in ./.venv/lib/python3.14/site-packages (from sqlalchemy>=2.0.42->carrot-transform) (4.15.0)
# Collecting lz4 (from trino>=0.335.0->carrot-transform)
#   Using cached lz4-4.4.5-cp314-cp314-macosx_10_15_x86_64.whl.metadata (3.8 kB)
# Collecting orjson>=3.11.0 (from trino>=0.335.0->carrot-transform)
#   Downloading orjson-3.11.5-cp314-cp314-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (41 kB)
# Collecting pytz (from trino>=0.335.0->carrot-transform)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: requests>=2.32.4 in ./.venv/lib/python3.14/site-packages (from trino>=0.335.0->carrot-transform) (2.32.5)
# Collecting tzlocal (from trino>=0.335.0->carrot-transform)
#   Using cached tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting zstandard (from trino>=0.335.0->carrot-transform)
#   Using cached zstandard-0.25.0-cp314-cp314-macosx_10_13_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.14/site-packages (from requests>=2.32.4->trino>=0.335.0->carrot-transform) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.14/site-packages (from requests>=2.32.4->trino>=0.335.0->carrot-transform) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.14/site-packages (from requests>=2.32.4->trino>=0.335.0->carrot-transform) (2026.1.4)
# Downloading carrot_transform-0.6.1-py3-none-any.whl (264 kB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Downloading awscli-1.44.13-py3-none-any.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 1.7 MB/s  0:00:021.7 MB/s eta 0:00:01:01
# Downloading botocore-1.42.23-py3-none-any.whl (14.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 2.7 MB/s  0:00:05 eta 0:00:010:01:01
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading docutils-0.19-py3-none-any.whl (570 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.5/570.5 kB 1.5 MB/s  0:00:00m 3.5 MB/s eta 0:00:01
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
# Downloading boto3-1.42.23-py3-none-any.whl (140 kB)
# Using cached psycopg2_binary-2.9.11-cp314-cp314-macosx_10_13_x86_64.whl (3.8 MB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading sqlalchemy-2.0.45-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 3.6 MB/s  0:00:003.6 MB/s eta 0:00:01
# Downloading greenlet-3.3.0-cp314-cp314-macosx_11_0_universal2.whl (275 kB)
# Using cached trino-0.336.0-py3-none-any.whl (57 kB)
# Downloading orjson-3.11.5-cp314-cp314-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (245 kB)
# Using cached lz4-4.4.5-cp314-cp314-macosx_10_15_x86_64.whl (207 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Using cached zstandard-0.25.0-cp314-cp314-macosx_10_13_x86_64.whl (795 kB)
# Installing collected packages: pytz, zstandard, tzlocal, pyasn1, psycopg2-binary, orjson, lz4, jmespath, greenlet, docutils, colorama, click, trino, sqlalchemy, rsa, botocore, s3transfer, boto3, awscli, carrot-transform
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20/20 [carrot-transform]2m19/20 [carrot-transform]
# Successfully installed awscli-1.44.13 boto3-1.42.23 botocore-1.42.23 carrot-transform-0.6.1 click-8.3.1 colorama-0.4.6 docutils-0.19 greenlet-3.3.0 jmespath-1.0.1 lz4-4.4.5 orjson-3.11.5 psycopg2-binary-2.9.11 pyasn1-0.6.1 pytz-2025.2 rsa-4.7.2 s3transfer-0.16.0 sqlalchemy-2.0.45 trino-0.336.0 tzlocal-5.3.1 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Run it

# %%
# !carrot-transform run_v2 folder \
  --input-dir @carrot/examples/test/inputs \
  --rules-file @carrot/examples/test/rules/v2.json \
  --person-file @carrot/examples/test/inputs/Demographics.csv \
  --output-dir carrottransform/examples/test/test_output \
  --omop-ddl-file @carrot/config/OMOPCDM_postgresql_5.4_ddl.sql

# %% [markdown]
# ## See what we got

# %%
from pathlib import Path

output_dir = Path('carrottransform/examples/test/test_output')
output_files = list(output_dir.glob("*.tsv"))

for file in sorted(output_files):
    size_kb = file.stat().st_size / 1024
    print(f"{file.name} ({size_kb:.1f} KB)")
